# %% [markdown]
# # Capstone project on Predicting Credit Card Approval

# %% [markdown]
# **Introduction**

# %% [markdown]
# Credit cards are one of the most commonly used financial tools. However, obtaining a credit card can be a difficult task for many individuals due to various factors such as income level, and employment status. To help streamline the application process and improve the approval rate, machine learning models can be used to predict credit card approval. In this project, we will explore how various factors affect credit card approval rates and use predictive models to improve the accuracy of credit card approval predictions.

# %% [markdown]
# In this project we have two datasets one is existing  information of the customer for the credit card approval and other the customer data who is approved elibity for approved or not aprroved we must know the accuracy of teh credit card approval prediction.

# %% [markdown]
# Attribute Descriptions

# %% [markdown]
# Gender: This column indicates the gender of the individual, either male or female. It is a Categorical column(binary).
#
# Car_Owner: This column indicates whether the individual has a car or not, either Yes or No.It is a Categorical column (binary).
#
# Propert_Owner: This column indicates whether the individual has a property or not, either Yes or No.It is a Categorical column (binary).
#
# Children: This column indicates the number of children the individual had.It is a Numerical column(integer).
#
# Annual_income: This column contains the annual income of the individual.It is a Numerical column (continuous).
#
# Type_Income: This column indicates the type of income the individual earns, such as salary or self-employed income.It is a Numerical (nominal).
#
# Education: This column indicates the level of education of the individual. It is a Categorical  (ordinal).
#
# Marital_status: This column indicates the marital status of the individual, such as Single, Married, Divorced. It is a Categorical (nominal).
#
# Housing_type: This column indicates the type of housing the individual lives in, such as a house ,rented or apartment. It is a Categorical (nominal).
#
# Birthday_count: This column contains the age of the individual.It is a Numerical(integer).
#
# Employed_days: This column indicates the number of days the individual has been employed.It is a Numerical(integer).
#
# Mobile_phone, Work_Phone, Phone, and Email_id: These columns contain contact information for the individual, such as mobile phone number, work phone number, home phone number, and email id.Mobile_phone, Work_Phone, Phone are Categorical (binary) and Email_id is Categorical (nominal).
#
# Type_Occupation: This column indicates the type of occupation of the individual, such as Manager,Corestaff,Drivers, healthcare or education. It is a Categorical (nominal).
#
# Family_Members: This column indicates the number of family members the individual had.It is a Numeric (integer).
#
# Label: This column contains the label for credit card approval, either approved or not approved. It is a Categorical (binary).

# %% [markdown]
# # Questions:-

# %% [markdown]
# 1) Why is your proposal important in today’s world? How predicting a good client is worthy for a bank?

# %% [markdown]
# Ans:- The proposal to predict credit card approval is highly relevant in today's world due to the increasing use of credit cards as a financial tool. With the rise in e-commerce and online transactions, credit cards have become a primary payment method for many individuals, making it essential for banks to efficiently process credit card applications and improve the approval rate. Predicting a good client is essential for a bank because it helps to minimize the risk of credit default and reduce the cost of managing credit card accounts. Banks can use machine learning algorithms to analyze various factors such as income level, employment status etc. By accurately predicting, banks can offer credit cards to clients with lower risk profiles, which can ultimately lead to better profitability and improved customer satisfaction.

# %% [markdown]
# 2) How is it going to impact the banking sector?

# %% [markdown]
# A) predicting credit card approval using machine learning can have a transformative impact on the banking sector by improving the customer experience, reducing risk, and increasing profitability and  banks can offer faster and more accurate credit card approvals, which can improve the overall customer experience. This can lead to increased customer satisfaction and loyalty, Machine learning algorithms can help banks to accurately predict the likelihood of a client defaulting on their credit card payments. By identifying clients with lower credit risk profiles, banks can offer credit cards with lower interest rates, which can reduce the risk of defaults and ultimately improve the bank's profitability.Credit scores play a crucial role in assessing the creditworthiness of an individual. Banks use this information to evaluate the risk associated with lending money or issuing credit cards to a particular customer.A higher credit score generally indicates a lower credit risk, and banks may be more willing to offer favorable terms and higher credit limits to customers with good credit histories. banks can increase their profitability. This can help banks to offer better rates and benefits to their clients, leading to increased market share and revenue. A higher credit score can lead to faster approvals and better terms for the customer .This efficiency is crucial for providing timely financial services to customers.

# %% [markdown]
# 3) If any, what is the gap in the knowledge or how your proposed method can be helpful if required in future for any bank in India.

# %% [markdown]
# A) If there is a gap in the knowledge or process used by a bank in India for credit card approval, the proposed method can be helpful for banks in India by improving the accuracy of credit card approval predictions, enhancing credit risk management strategies, and improving efficiency. However, to fully leverage the benefits of our proposed method, banks will need to ensure that they have access to reliable and comprehensive data sources.

# %% [markdown]
# # Data Understanding

# %%
print("My first capstone project")
# Out:
# My first capstone project

# %% [markdown]
# # Importing all libraries

# %%
#install pyforest
# !pip install pyforest
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pyforest: filename=pyforest-1.1.0-py2.py3-none-any.whl size=14606 sha256=7f0ca30f2cf165becc2fa0ff6d847faf8d6551388d633786f679990b66837e17
#   Stored in directory: /root/.cache/pip/wheels/9e/7d/2c/5d2f5e62de376c386fd3bf5a8e5bd119ace6a9f48f49df6017
# Successfully built pyforest
# ...

# %%
# Importing libraries

import pandas as pd # for data analysis
import numpy as np # for numerical calculations and dealing with vectors and matrices
import seaborn as sns # visualization
import matplotlib.pyplot as plt # for visualization
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Read the dataset using pandas library

# %%
df=pd.read_csv("Credit_card.csv") # load the dataset
df1=pd.read_csv("Credit_card_label.csv")

# %% [markdown]
# # Data visualization and  Cleaning

# %%
df.head(5) # see the sample of dataset first top 5 rows.
# Out:
#     Ind_ID GENDER Car_Owner Propert_Owner  CHILDREN  Annual_income  \
# 0  5008827      M         Y             Y         0       180000.0
# 1  5009744      F         Y             N         0       315000.0
# 2  5009746      F         Y             N         0       315000.0
# 3  5009749      F         Y             N         0            NaN
# 4  5009752      F         Y             N         0       315000.0
#
#             Type_Income         EDUCATION Marital_status       Housing_type  \
# 0             Pensioner  Higher education        Married  House / apartment
# 1  Commercial associate  Higher education        Married  House / apartment
# 2  Commercial associate  Higher education        Married  House / apartment
# 3  Commercial associate  Higher education        Married  House / apartment
# 4  Commercial associate  Higher education        Married  House / apartment
#
#    Birthday_count  Employed_days  Mobile_phone  Work_Phone  Phone  EMAIL_ID  \
# ...

# %%
df1.head()
# Out:
#     Ind_ID  label
# 0  5008827      1
# 1  5009744      1
# 2  5009746      1
# 3  5009749      1
# 4  5009752      1

# %%
df.shape # shape of dataset
# Out:
# (1548, 18)

# %%
df1.shape
# Out:
# (1548, 2)

# %%
#seeing duplicate values in dataset
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Ind_ID, GENDER, Car_Owner, Propert_Owner, CHILDREN, Annual_income, Type_Income, EDUCATION, Marital_status, Housing_type, Birthday_count, Employed_days, Mobile_phone, Work_Phone, Phone, EMAIL_ID, Type_Occupation, Family_Members]
# Index: []

# %%
df.info() # infoprmation of the data set
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1548 entries, 0 to 1547
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Ind_ID           1548 non-null   int64
#  1   GENDER           1541 non-null   object
#  2   Car_Owner        1548 non-null   object
#  3   Propert_Owner    1548 non-null   object
#  4   CHILDREN         1548 non-null   int64
#  5   Annual_income    1525 non-null   float64
#  6   Type_Income      1548 non-null   object
#  7   EDUCATION        1548 non-null   object
#  8   Marital_status   1548 non-null   object
#  9   Housing_type     1548 non-null   object
#  10  Birthday_count   1526 non-null   float64
#  11  Employed_days    1548 non-null   int64
#  12  Mobile_phone     1548 non-null   int64
#  13  Work_Phone       1548 non-null   int64
#  14  Phone            1548 non-null   int64
#  15  EMAIL_ID         1548 non-null   int64
#  16  Type_Occupation  1060 non-null   object
# ...

# %%
df.columns
# Out:
# Index(['Ind_ID', 'GENDER', 'Car_Owner', 'Propert_Owner', 'CHILDREN',
#        'Annual_income', 'Type_Income', 'EDUCATION', 'Marital_status',
#        'Housing_type', 'Birthday_count', 'Employed_days', 'Mobile_phone',
#        'Work_Phone', 'Phone', 'EMAIL_ID', 'Type_Occupation', 'Family_Members'],
#       dtype='object')

# %%
# Rename the columns names.
df=df.rename(columns={'Ind_ID':'Ind_ID','GENDER':'Gender','CHILDREN':'Children','EDUCATION':'Education','Birthday_count':'Age','Employed_days':'Work_exp','EMAIL_ID':'Email_id'})

# %%
df.columns
# Out:
# Index(['Ind_ID', 'Gender', 'Car_Owner', 'Propert_Owner', 'Children',
#        'Annual_income', 'Type_Income', 'Education', 'Marital_status',
#        'Housing_type', 'Age', 'Work_exp', 'Mobile_phone', 'Work_Phone',
#        'Phone', 'Email_id', 'Type_Occupation', 'Family_Members'],
#       dtype='object')

# %%
# In this project they given two datasets separetly so we want to join the datasets using merg command from pandas library.
df2=pd.merge(df,df1,how='inner',on=['Ind_ID'])

# %%
df2.head()
# Out:
#     Ind_ID Gender Car_Owner Propert_Owner  Children  Annual_income  \
# 0  5008827      M         Y             Y         0       180000.0
# 1  5009744      F         Y             N         0       315000.0
# 2  5009746      F         Y             N         0       315000.0
# 3  5009749      F         Y             N         0            NaN
# 4  5009752      F         Y             N         0       315000.0
#
#             Type_Income         Education Marital_status       Housing_type  \
# 0             Pensioner  Higher education        Married  House / apartment
# 1  Commercial associate  Higher education        Married  House / apartment
# 2  Commercial associate  Higher education        Married  House / apartment
# 3  Commercial associate  Higher education        Married  House / apartment
# 4  Commercial associate  Higher education        Married  House / apartment
#
#        Age  Work_exp  Mobile_phone  Work_Phone  Phone  Email_id  \
# ...

# %%
df2.isnull().sum()
# Out:
# Ind_ID               0
# Gender               7
# Car_Owner            0
# Propert_Owner        0
# Children             0
# Annual_income       23
# Type_Income          0
# Education            0
# Marital_status       0
# Housing_type         0
# Age                 22
# Work_exp             0
# Mobile_phone         0
# Work_Phone           0
# Phone                0
# Email_id             0
# Type_Occupation    488
# Family_Members       0
# label                0
# dtype: int64

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1548 entries, 0 to 1547
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Ind_ID           1548 non-null   int64
#  1   Gender           1541 non-null   object
#  2   Car_Owner        1548 non-null   object
#  3   Propert_Owner    1548 non-null   object
#  4   Children         1548 non-null   int64
#  5   Annual_income    1525 non-null   float64
#  6   Type_Income      1548 non-null   object
#  7   Education        1548 non-null   object
#  8   Marital_status   1548 non-null   object
#  9   Housing_type     1548 non-null   object
#  10  Age              1526 non-null   float64
#  11  Work_exp         1548 non-null   int64
#  12  Mobile_phone     1548 non-null   int64
#  13  Work_Phone       1548 non-null   int64
#  14  Phone            1548 non-null   int64
#  15  Email_id         1548 non-null   int64
#  16  Type_Occupation  1060 non-null   object
# ...

# %%
df2["Type_Income"].value_counts()
# Out:
# Working                 798
# Commercial associate    365
# Pensioner               269
# State servant           116
# Name: Type_Income, dtype: int64

# %%
df2["Housing_type"].value_counts()
# Out:
# House / apartment      1380
# With parents             80
# Municipal apartment      53
# Rented apartment         21
# Office apartment          9
# Co-op apartment           5
# Name: Housing_type, dtype: int64

# %%
df2["Education"].value_counts()
# Out:
# Secondary / secondary special    1031
# Higher education                  426
# Incomplete higher                  68
# Lower secondary                    21
# Academic degree                     2
# Name: Education, dtype: int64

# %%
df2.describe()
# Out:
#              Ind_ID     Children  Annual_income           Age       Work_exp  \
# count  1.548000e+03  1548.000000   1.525000e+03   1526.000000    1548.000000
# mean   5.078920e+06     0.412791   1.913993e+05 -16040.342071   59364.689922
# std    4.171759e+04     0.776691   1.132530e+05   4229.503202  137808.062701
# min    5.008827e+06     0.000000   3.375000e+04 -24946.000000  -14887.000000
# 25%    5.045070e+06     0.000000   1.215000e+05 -19553.000000   -3174.500000
# 50%    5.078842e+06     0.000000   1.665000e+05 -15661.500000   -1565.000000
# 75%    5.115673e+06     1.000000   2.250000e+05 -12417.000000    -431.750000
# max    5.150412e+06    14.000000   1.575000e+06  -7705.000000  365243.000000
#
#        Mobile_phone   Work_Phone        Phone     Email_id  Family_Members  \
# count        1548.0  1548.000000  1548.000000  1548.000000     1548.000000
# mean            1.0     0.208010     0.309432     0.092377        2.161499
# ...

# %%
import missingno as msno #exploring missing values
msno.bar(df2)
# Out:
# <Axes: >

# %%
import missingno as msno #exploring missing values
msno.matrix(df2)
# Out:
# <Axes: >

# %%
#visualising the missing values in heatmap
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df2
# Out:
#        Ind_ID Gender Car_Owner Propert_Owner  Children  Annual_income  \
# 0     5008827      M         Y             Y         0       180000.0
# 1     5009744      F         Y             N         0       315000.0
# 2     5009746      F         Y             N         0       315000.0
# 3     5009749      F         Y             N         0            NaN
# 4     5009752      F         Y             N         0       315000.0
# ...       ...    ...       ...           ...       ...            ...
# 1543  5028645      F         N             Y         0            NaN
# 1544  5023655      F         N             N         0       225000.0
# 1545  5115992      M         Y             Y         2       180000.0
# 1546  5118219      M         Y             N         0       270000.0
# 1547  5053790      F         Y             Y         0       225000.0
#
#                Type_Income                      Education  \
# 0                Pensioner               Higher education
# ...

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# # Imputing the missing values

# %%
#imputation for missing values for annual_income and Birthday_count by using simpleImputer from sklearn.
numerical_imputer=SimpleImputer(strategy='mean')
#feature enginnering
df2[['Annual_income','Age']]=numerical_imputer.fit_transform(df2[['Annual_income','Age']])

# %%
df2.isnull().sum()
# Out:
# Ind_ID               0
# Gender               7
# Car_Owner            0
# Propert_Owner        0
# Children             0
# Annual_income        0
# Type_Income          0
# Education            0
# Marital_status       0
# Housing_type         0
# Age                  0
# Work_exp             0
# Mobile_phone         0
# Work_Phone           0
# Phone                0
# Email_id             0
# Type_Occupation    488
# Family_Members       0
# label                0
# dtype: int64

# %%
#replace missing values using pandas
df2['Type_Occupation'].fillna('Others',inplace=True)

# %%
#Delete the null values in the gender column
df2=df2.dropna(subset=["Gender"])

# %%
df2.head(5)
# Out:
#     Ind_ID Gender Car_Owner Propert_Owner  Children  Annual_income  \
# 0  5008827      M         Y             Y         0   180000.00000
# 1  5009744      F         Y             N         0   315000.00000
# 2  5009746      F         Y             N         0   315000.00000
# 3  5009749      F         Y             N         0   191399.32623
# 4  5009752      F         Y             N         0   315000.00000
#
#             Type_Income         Education Marital_status       Housing_type  \
# 0             Pensioner  Higher education        Married  House / apartment
# 1  Commercial associate  Higher education        Married  House / apartment
# 2  Commercial associate  Higher education        Married  House / apartment
# 3  Commercial associate  Higher education        Married  House / apartment
# 4  Commercial associate  Higher education        Married  House / apartment
#
#             Age  Work_exp  Mobile_phone  Work_Phone  Phone  Email_id  \
# ...

# %%
df2.shape
# Out:
# (1541, 19)

# %%
import missingno as msno
msno.matrix(df2)
# Out:
# <Axes: >

# %%
df2.head()
# Out:
#     Ind_ID Gender Car_Owner Propert_Owner  Children  Annual_income  \
# 0  5008827      M         Y             Y         0   180000.00000
# 1  5009744      F         Y             N         0   315000.00000
# 2  5009746      F         Y             N         0   315000.00000
# 3  5009749      F         Y             N         0   191399.32623
# 4  5009752      F         Y             N         0   315000.00000
#
#             Type_Income         Education Marital_status       Housing_type  \
# 0             Pensioner  Higher education        Married  House / apartment
# 1  Commercial associate  Higher education        Married  House / apartment
# 2  Commercial associate  Higher education        Married  House / apartment
# 3  Commercial associate  Higher education        Married  House / apartment
# 4  Commercial associate  Higher education        Married  House / apartment
#
#             Age  Work_exp  Mobile_phone  Work_Phone  Phone  Email_id  \
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1541 entries, 0 to 1547
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Ind_ID           1541 non-null   int64
#  1   Gender           1541 non-null   object
#  2   Car_Owner        1541 non-null   object
#  3   Propert_Owner    1541 non-null   object
#  4   Children         1541 non-null   int64
#  5   Annual_income    1541 non-null   float64
#  6   Type_Income      1541 non-null   object
#  7   Education        1541 non-null   object
#  8   Marital_status   1541 non-null   object
#  9   Housing_type     1541 non-null   object
#  10  Age              1541 non-null   float64
#  11  Work_exp         1541 non-null   int64
#  12  Mobile_phone     1541 non-null   int64
#  13  Work_Phone       1541 non-null   int64
#  14  Phone            1541 non-null   int64
#  15  Email_id         1541 non-null   int64
#  16  Type_Occupation  1541 non-null   object
# ...

# %%
df2.isnull().sum()
# Out:
# Ind_ID             0
# Gender             0
# Car_Owner          0
# Propert_Owner      0
# Children           0
# Annual_income      0
# Type_Income        0
# Education          0
# Marital_status     0
# Housing_type       0
# Age                0
# Work_exp           0
# Mobile_phone       0
# Work_Phone         0
# Phone              0
# Email_id           0
# Type_Occupation    0
# Family_Members     0
# label              0
# dtype: int64

# %%
#converting the negative values to postive values for Age column.
df2['Age']=abs(round((df2['Age']/-365),0))

# %%
#Coverting the negative values to postive values for Work_exp column
df2['Work_exp']=abs(round((df2['Work_exp']/-365),0))

# %%
df2.head()
# Out:
#     Ind_ID Gender Car_Owner Propert_Owner  Children  Annual_income  \
# 0  5008827      M         Y             Y         0   180000.00000
# 1  5009744      F         Y             N         0   315000.00000
# 2  5009746      F         Y             N         0   315000.00000
# 3  5009749      F         Y             N         0   191399.32623
# 4  5009752      F         Y             N         0   315000.00000
#
#             Type_Income         Education Marital_status       Housing_type  \
# 0             Pensioner  Higher education        Married  House / apartment
# 1  Commercial associate  Higher education        Married  House / apartment
# 2  Commercial associate  Higher education        Married  House / apartment
# 3  Commercial associate  Higher education        Married  House / apartment
# 4  Commercial associate  Higher education        Married  House / apartment
#
#     Age  Work_exp  Mobile_phone  Work_Phone  Phone  Email_id Type_Occupation  \
# ...

# %%
df2['Work_exp'].replace(1001.0,0,inplace=True)

# %%
df2.head(8)
# Out:
#     Ind_ID Gender Car_Owner Propert_Owner  Children  Annual_income  \
# 0  5008827      M         Y             Y         0   180000.00000
# 1  5009744      F         Y             N         0   315000.00000
# 2  5009746      F         Y             N         0   315000.00000
# 3  5009749      F         Y             N         0   191399.32623
# 4  5009752      F         Y             N         0   315000.00000
# 6  5009754      F         Y             N         0   315000.00000
# 7  5009894      F         N             N         0   180000.00000
# 8  5010864      M         Y             Y         1   450000.00000
#
#             Type_Income                      Education Marital_status  \
# 0             Pensioner               Higher education        Married
# 1  Commercial associate               Higher education        Married
# 2  Commercial associate               Higher education        Married
# 3  Commercial associate               Higher education        Married
# ...

# %%
df2 = pd.DataFrame(df2) # checking correlation
print(df2.corr(method = 'spearman'))
# Out:
#                   Ind_ID  Children  Annual_income       Age  Work_exp  \
# Ind_ID          1.000000  0.026155      -0.011117 -0.023564  0.025145
# Children        0.026155  1.000000       0.064120 -0.336771  0.156326
# Annual_income  -0.011117  0.064120       1.000000 -0.106760  0.165777
# Age            -0.023564 -0.336771      -0.106760  1.000000 -0.195991
# Work_exp        0.025145  0.156326       0.165777 -0.195991  1.000000
# Mobile_phone         NaN       NaN            NaN       NaN       NaN
# Work_Phone      0.088004  0.040402      -0.069633 -0.164662  0.159235
# Phone           0.007702  0.014571      -0.020205  0.036688  0.008315
# Email_id       -0.044812  0.055700       0.116949 -0.161943 -0.004001
# Family_Members  0.007507  0.814514       0.039158 -0.276376  0.182474
# label           0.016660 -0.014037      -0.000154  0.048210 -0.100412
#
#                 Mobile_phone  Work_Phone     Phone  Email_id  Family_Members  \
# ...

# %%
for i in df2:
  if df2[i].dtype=="object":
    print(i,df2[i].value_counts())
    print("---------")
# Out:
# Gender F    973
# M    568
# Name: Gender, dtype: int64
# ---------
# Car_Owner N    922
# Y    619
# Name: Car_Owner, dtype: int64
# ---------
# Propert_Owner Y    1007
# N     534
# Name: Propert_Owner, dtype: int64
# ---------
# Type_Income Working                 795
# Commercial associate    364
# Pensioner               267
# State servant           115
# Name: Type_Income, dtype: int64
# ---------
# Education Secondary / secondary special    1029
# Higher education                  421
# Incomplete higher                  68
# Lower secondary                    21
# Academic degree                     2
# Name: Education, dtype: int64
# ---------
# Marital_status Married                 1044
# Single / not married     226
# Civil marriage           101
# Separated                 95
# Widow                     75
# Name: Marital_status, dtype: int64
# ---------
# Housing_type House / apartment      1374
# With parents             79
# Municipal apartment      53
# ...

# %% [markdown]
# # Data visualizing in graph plots using python

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming 'Gender' is the name of the column in your DataFrame
gender_count = df2['Gender'].value_counts()

# Create a bar plot using Matplotlib
plt.bar(gender_count.index, gender_count.values, color='purple')

# Adding labels and title for better readability
plt.xlabel('Gender')
plt.ylabel('Count')

 #Make sure you haven't accidentally assigned a string to plt before calling title
#plt.title('Distribution of Gender in the DataFrame')

# Display the plot
plt.show()

# %%
sns.countplot(x=df2["Gender"])
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
Occupation_count=df2['Type_Occupation'].value_counts()
plt.figure(figsize=(10,6))
#creat barpolt using Matplotlib
plt.bar(Occupation_count.index,Occupation_count.values)
plt.xlabel('Type_Occupation')
plt.ylabel('Count')
plt.xticks(rotation = 'vertical')
#plt.title('Distribution of Phone')
plt.show()

# %%
# count number of children had for individuals
plt.hist(df2["Children"],color="pink")
#plt.title("Count_Children")
plt.xlabel("Children")
plt.ylabel("count")
plt.show()

# %%
sns.countplot(x=df2["Car_Owner"],hue=df2["Gender"])
# Out:
# <Axes: xlabel='Car_Owner', ylabel='count'>

# %%
plt.figure(figsize=(10,8))
sns.boxplot(x=df2["Ind_ID"],y=df2['Propert_Owner'],hue=df2["Gender"])
#plt.title('Boxplot of Property Ownership by Individual ID and Gender')
# Out:
# <Axes: xlabel='Ind_ID', ylabel='Propert_Owner'>

# %% [markdown]
# Insights:-
#    In this graph we visualize the gender have the  property_owner.we can compare the median and spread of property ownership values between different "Individual ID" groups. This helps identify patterns or differences in property ownership across individuals.The visualization helps in understanding the distribution of property ownership and potential differences between individual IDs while considering gender as a factor.the central tendency and spread of property ownership values for each "Individual ID" and "Gender" combination.

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(df2,x='Annual_income',y='Age',hue='Type_Occupation',color="Darkpink",marker='H')
plt.title="Annual income based on age and Occupation"
plt.show()

# %% [markdown]
# You can observe how annual income varies across different age groups. Look for trends such as whether income tends to increase, decrease, or remain stable with age.
# Are there specific age ranges where individuals tend to have higher or lower annual incomes.

# %%
# distribution of age with each of the gender, age and gender
sns.boxplot(x=df2["Gender"],y=df2["Age"])
# Out:
# <Axes: xlabel='Gender', ylabel='Age'>

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(df2,x="Ind_ID",y="Annual_income",hue=df2['Gender'])
plt.xlabel('Ind_ID')
plt.ylabel('Annual_income')
# Out:
# Text(0, 0.5, 'Annual_income')

# %%
plt.figure(figsize=(10,6))
sns.boxplot(df2["Annual_income"])
plt.show()

# %% [markdown]
# Insights:-
# In this graph shows that outilers in annual income.Identify any outliers or individual cases that deviate significantly from the general trends. These outliers can provide insights into unique situations, such as individuals with high income for their age or unusual occupations.

# %%
df2.head()
# Out:
#     Ind_ID Gender Car_Owner Propert_Owner  Children  Annual_income  \
# 0  5008827      M         Y             Y         0   180000.00000
# 1  5009744      F         Y             N         0   315000.00000
# 2  5009746      F         Y             N         0   315000.00000
# 3  5009749      F         Y             N         0   191399.32623
# 4  5009752      F         Y             N         0   315000.00000
#
#             Type_Income         Education Marital_status       Housing_type  \
# 0             Pensioner  Higher education        Married  House / apartment
# 1  Commercial associate  Higher education        Married  House / apartment
# 2  Commercial associate  Higher education        Married  House / apartment
# 3  Commercial associate  Higher education        Married  House / apartment
# 4  Commercial associate  Higher education        Married  House / apartment
#
#     Age  Work_exp  Mobile_phone  Work_Phone  Phone  Email_id Type_Occupation  \
# ...

# %%
for i in df2:
  if df2[i].dtype=="object":
    print(i,df2[i].value_counts())
    print("---------")
# Out:
# Gender F    973
# M    568
# Name: Gender, dtype: int64
# ---------
# Car_Owner N    922
# Y    619
# Name: Car_Owner, dtype: int64
# ---------
# Propert_Owner Y    1007
# N     534
# Name: Propert_Owner, dtype: int64
# ---------
# Type_Income Working                 795
# Commercial associate    364
# Pensioner               267
# State servant           115
# Name: Type_Income, dtype: int64
# ---------
# Education Secondary / secondary special    1029
# Higher education                  421
# Incomplete higher                  68
# Lower secondary                    21
# Academic degree                     2
# Name: Education, dtype: int64
# ---------
# Marital_status Married                 1044
# Single / not married     226
# Civil marriage           101
# Separated                 95
# Widow                     75
# Name: Marital_status, dtype: int64
# ---------
# Housing_type House / apartment      1374
# With parents             79
# Municipal apartment      53
# ...

# %%
df2.describe()
# Out:
#              Ind_ID     Children  Annual_income          Age     Work_exp  \
# count  1.541000e+03  1541.000000   1.541000e+03  1541.000000  1541.000000
# mean   5.078979e+06     0.413368   1.908057e+05    43.974692     6.075276
# std    4.167137e+04     0.777811   1.121136e+05    11.517294     6.599256
# min    5.008827e+06     0.000000   3.375000e+04    21.000000     0.000000
# 25%    5.045113e+06     0.000000   1.215000e+05    34.000000     1.000000
# 50%    5.078924e+06     0.000000   1.710000e+05    43.000000     4.000000
# 75%    5.115671e+06     1.000000   2.250000e+05    53.000000     9.000000
# max    5.150412e+06    14.000000   1.575000e+06    68.000000    41.000000
#
#        Mobile_phone   Work_Phone        Phone     Email_id  Family_Members  \
# count        1541.0  1541.000000  1541.000000  1541.000000     1541.000000
# mean            1.0     0.208306     0.308241     0.092148        2.162232
# std             0.0     0.406229     0.461917     0.289329        0.948492
# ...

# %% [markdown]
# # Handling Outliers in Data cleaning

# %%
df2["Annual_income"].plot(kind="box")
# Out:
# <Axes: >

# %%
df2_outlier=df2.copy()

# %%
df2_outlier.describe()["Annual_income"]
# Out:
# count    1.541000e+03
# mean     1.908057e+05
# std      1.121136e+05
# min      3.375000e+04
# 25%      1.215000e+05
# 50%      1.710000e+05
# 75%      2.250000e+05
# max      1.575000e+06
# Name: Annual_income, dtype: float64

# %%
# lower limit= q1-1.5*IQR
# upper limit=q3+1.5*IQR

q1=df2_outlier.describe()["Annual_income"]["25%"]
print(q1)
q3=df2_outlier.describe()["Annual_income"]["75%"]
print(q3)
# Out:
# 121500.0
# 225000.0

# %%
# IQR=q3-q1
IQR=q3-q1
print(IQR)
# Out:
# 103500.0

# %%
lower_limit= q1-1.5*IQR
upper_limit=q3+1.5*IQR

# %%
print(lower_limit)
print(upper_limit)
# Out:
# -33750.0
# 380250.0

# %%
df2_outlier["Annual_income"]=df2_outlier["Annual_income"].clip(lower_limit,upper_limit)

# %%
plt.figure(figsize=(15,8))
plt.subplot(1,2,1)
df2_outlier["Annual_income"].plot(kind="box") # after clipping outliners in annual income columnn
plt.subplot(1,2,2)
df2["Annual_income"].plot(kind="box")
# Out:
# <Axes: >

# %%
df2["Annual_income"]=df2_outlier["Annual_income"].clip(lower_limit,upper_limit)

# %%
df2["Age"].plot(kind="box")
# Out:
# <Axes: >

# %%
df2.head(5)
# Out:
#     Ind_ID Gender Car_Owner Propert_Owner  Children  Annual_income  \
# 0  5008827      M         Y             Y         0   180000.00000
# 1  5009744      F         Y             N         0   315000.00000
# 2  5009746      F         Y             N         0   315000.00000
# 3  5009749      F         Y             N         0   191399.32623
# 4  5009752      F         Y             N         0   315000.00000
#
#             Type_Income         Education Marital_status       Housing_type  \
# 0             Pensioner  Higher education        Married  House / apartment
# 1  Commercial associate  Higher education        Married  House / apartment
# 2  Commercial associate  Higher education        Married  House / apartment
# 3  Commercial associate  Higher education        Married  House / apartment
# 4  Commercial associate  Higher education        Married  House / apartment
#
#     Age  Work_exp  Mobile_phone  Work_Phone  Phone  Email_id Type_Occupation  \
# ...

# %%
df2_outlier1=df2.copy()

# %%
df2_outlier.describe()["Family_Members"]
# Out:
# count    1541.000000
# mean        2.162232
# std         0.948492
# min         1.000000
# 25%         2.000000
# 50%         2.000000
# 75%         3.000000
# max        15.000000
# Name: Family_Members, dtype: float64

# %%
# lower limit= q1-1.5*IQR
# upper limit=q3+1.5*IQR

q1=df2_outlier1.describe()["Family_Members"]["25%"]
print(q1)
q3=df2_outlier1.describe()["Family_Members"]["75%"]
print(q3)
# Out:
# 2.0
# 3.0

# %%
# IQR=q3-q1
IQR=q3-q1
print(IQR)
# Out:
# 1.0

# %%
lower_limit= q1-1.5*IQR
upper_limit=q3+1.5*IQR

# %%
print(lower_limit)
print(upper_limit)
# Out:
# 0.5
# 4.5

# %%
df2_outlier1["Family_Members"]=df2_outlier1["Family_Members"].clip(lower_limit,upper_limit)

# %%
plt.figure(figsize=(15,8))
plt.subplot(1,2,1)
df2_outlier1["Family_Members"].plot(kind="box")
plt.subplot(1,2,2)
df2["Family_Members"].plot(kind="box")
# Out:
# <Axes: >

# %%
df2["Family_Members"]=df2_outlier1["Family_Members"].clip(lower_limit,upper_limit)

# %%
sns.barplot(x ='Family_Members',y ="Children",data=df2)
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(df2,x='Annual_income',y='Age',hue='Type_Occupation',color="Darkpink",marker='H')
plt.title="Annual income based on age and Occupation"
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(df2,x="Age",y="Work_exp",hue="Type_Occupation")
# Adding a title to the plot
#plt.title("Scatter Plot of Age vs. Work Experience by Occupation")
# Displaying the plot
plt.show()

# %% [markdown]
# Insights:- In this graph the data shows the people witha age and work_epxeerience having different occupations .Explore the relationship between age and work experience. Look for trends such as whether work experience tends to increase or decrease with age.Identify any outliers or individual cases that deviate significantly from the general trends. Outliers may represent individuals with unique combinations of age and work experience.

# %%
plt.figure(figsize=(15,8))
sns.barplot(df2,x="Housing_type",y="Annual_income", hue='Gender')
plt.xlabel('housing type')
plt.ylabel('Annual_income')
# Out:
# Text(0, 0.5, 'Annual_income')

# %% [markdown]
# Insights:-
# The bar plot allows for a visual comparison of annual incomes across different housing types. Each bar represents the average or total annual income for a specific housing type.Housing Type Impact on Annual Income to compare the heights of the bars to identify whether certain housing types are associated with higher or lower annual incomes.

# %%
plt.figure(figsize=(15,10))
df2["Housing_type"].value_counts().plot(kind="pie",autopct="%1.1f%%")
# Out:
# <Axes: ylabel='Housing_type'>

# %% [markdown]
# Proportion of Housing Types:
#
# The pie chart visually represents the proportion of each housing type in the dataset. Each slice of the pie corresponds to a specific housing type, and the size of each slice indicates its proportion relative to the whole.
# Majority Housing Type:
#
# Identify the largest slice of the pie, which represents the most prevalent housing type in the dataset. This information provides insights into the dominant category of housing among the individuals.
# Minority Housing Types:
#
# Smaller slices represent less common housing types. This information is valuable for understanding the diversity of housing types within the dataset.
# Imbalances or Disparities:

# %%
plt.figure(figsize=(15,10))
df2["label"].value_counts().plot(kind="pie",autopct="%1.1f%%")
# Out:
# <Axes: ylabel='label'>

# %% [markdown]
# Insights:-Label: 0 is application approved and 1 is application rejected.In this graph most of the appliactions are approved for credit card is 89% and the people with low annual income and and property and housingtype are not paying bills loan are rejected credit card 11%.

# %%
plt.figure(figsize=(15,8))
sns.scatterplot(df2,x="Ind_ID",y="Annual_income",hue=df2['label'])
plt.xlabel('Ind_ID')
plt.ylabel('Annual_income')
# Out:
# Text(0, 0.5, 'Annual_income')

# %% [markdown]
# Insights:-
#
# In this graph we see that with higher income the creditcard approval by seeing the annual income of the customer and the data information of that proper paying of the payments to the bank in time.. with out any delay is there chance to approve the credit card or not approved.

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(df2,x='Annual_income',y='Age',hue='Type_Income',color="Darkpink",marker='H')
plt.title="Annual income based on work or pension"
plt.show()

# %%
plt.figure(figsize=(20,4))
sns.countplot(x=df2["Marital_status"],hue=df2['label'],data=df2)
#plt.title("Marital_status vs label")
plt.xticks(rotation=0)
# Out:
# ([0, 1, 2, 3, 4],
#  [Text(0, 0, 'Married'),
#   Text(1, 0, 'Single / not married'),
#   Text(2, 0, 'Civil marriage'),
#   Text(3, 0, 'Separated'),
#   Text(4, 0, 'Widow')])

# %% [markdown]
# Insights:-
# In this  graph we saw mnost of the married people had applied for credit card approved and got approved.

# %%
plt.figure(figsize=(20,12))
sns.boxplot(x ='Age',y ="Annual_income",data=df2,color='pink')
plt.show()

# %%
df2.isnull().sum()
# Out:
# Ind_ID             0
# Gender             0
# Car_Owner          0
# Propert_Owner      0
# Children           0
# Annual_income      0
# Type_Income        0
# Education          0
# Marital_status     0
# Housing_type       0
# Age                0
# Work_exp           0
# Mobile_phone       0
# Work_Phone         0
# Phone              0
# Email_id           0
# Type_Occupation    0
# Family_Members     0
# label              0
# dtype: int64

# %%
df2.head(10)
# Out:
#      Ind_ID Gender Car_Owner Propert_Owner  Children  Annual_income  \
# 0   5008827      M         Y             Y         0   180000.00000
# 1   5009744      F         Y             N         0   315000.00000
# 2   5009746      F         Y             N         0   315000.00000
# 3   5009749      F         Y             N         0   191399.32623
# 4   5009752      F         Y             N         0   315000.00000
# 6   5009754      F         Y             N         0   315000.00000
# 7   5009894      F         N             N         0   180000.00000
# 8   5010864      M         Y             Y         1   380250.00000
# 9   5010868      M         Y             Y         1   380250.00000
# 10  5010869      M         Y             Y         1   380250.00000
#
#              Type_Income                      Education        Marital_status  \
# 0              Pensioner               Higher education               Married
# ...

# %%
df2.to_csv("final_project.csv")

# %% [markdown]
# # Data Preprocessing

# %%
for i in df2:
  if df2[i].dtype =="object":
    print(i,'\n')
    print(i,df2[i].value_counts())
    print("---------")
# Out:
# Gender
#
# Gender F    973
# M    568
# Name: Gender, dtype: int64
# ---------
# Car_Owner
#
# Car_Owner N    922
# Y    619
# Name: Car_Owner, dtype: int64
# ---------
# Propert_Owner
#
# Propert_Owner Y    1007
# N     534
# Name: Propert_Owner, dtype: int64
# ---------
# Type_Income
#
# Type_Income Working                 795
# Commercial associate    364
# Pensioner               267
# State servant           115
# Name: Type_Income, dtype: int64
# ---------
# Education
#
# Education Secondary / secondary special    1029
# Higher education                  421
# Incomplete higher                  68
# Lower secondary                    21
# Academic degree                     2
# Name: Education, dtype: int64
# ---------
# Marital_status
#
# Marital_status Married                 1044
# Single / not married     226
# Civil marriage           101
# Separated                 95
# Widow                     75
# Name: Marital_status, dtype: int64
# ---------
# Housing_type
#
# ...

# %%
 #checking correlation between variables using spearman rank correlation.
df3=df2.corr(method = 'spearman')
df3
# Out:
#                   Ind_ID  Children  Annual_income       Age  Work_exp  \
# Ind_ID          1.000000  0.026155      -0.011103 -0.023564  0.025145
# Children        0.026155  1.000000       0.063670 -0.336771  0.156326
# Annual_income  -0.011103  0.063670       1.000000 -0.106655  0.165930
# Age            -0.023564 -0.336771      -0.106655  1.000000 -0.195991
# Work_exp        0.025145  0.156326       0.165930 -0.195991  1.000000
# Mobile_phone         NaN       NaN            NaN       NaN       NaN
# Work_Phone      0.088004  0.040402      -0.069352 -0.164662  0.159235
# Phone           0.007702  0.014571      -0.020026  0.036688  0.008315
# Email_id       -0.044812  0.055700       0.117066 -0.161943 -0.004001
# Family_Members  0.007504  0.814514       0.038872 -0.276401  0.182466
# label           0.016660 -0.014037      -0.000240  0.048210 -0.100412
#
#                 Mobile_phone  Work_Phone     Phone  Email_id  Family_Members  \
# ...

# %%
plt.figure(figsize=(20,12))
sns.heatmap(df3,annot=True)
# Out:
# <Axes: >

# %%
#droping unused columns from dataframe.
df2=df2.drop(['Mobile_phone','Work_Phone','Phone','Email_id'],axis=1)

# %%
df2.isnull().sum()
# Out:
# Ind_ID             0
# Gender             0
# Car_Owner          0
# Propert_Owner      0
# Children           0
# Annual_income      0
# Type_Income        0
# Education          0
# Marital_status     0
# Housing_type       0
# Age                0
# Work_exp           0
# Type_Occupation    0
# Family_Members     0
# label              0
# dtype: int64

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# Feature Engineering - It is the process of transforming the features that better represent the underlying problem to predictive models, resulting in improved model accuracy on unseen data.It includes feature creation, Feature scaling,feature extraction and feature selection.

# %%
#converting cateroical columns into numerical columns using labelencoder.
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for i in df2:
  if df2[i].dtype=='object':
    df2[i]=le.fit_transform(df2[i])

# %%
df2.head()
# Out:
#     Ind_ID  Gender  Car_Owner  Propert_Owner  Children  Annual_income  \
# 0  5008827       1          1              1         0   180000.00000
# 1  5009744       0          1              0         0   315000.00000
# 2  5009746       0          1              0         0   315000.00000
# 3  5009749       0          1              0         0   191399.32623
# 4  5009752       0          1              0         0   315000.00000
#
#    Type_Income  Education  Marital_status  Housing_type   Age  Work_exp  \
# 0            1          1               1             1  51.0       0.0
# 1            0          1               1             1  37.0       2.0
# 2            0          1               1             1  44.0       2.0
# 3            0          1               1             1  37.0       2.0
# 4            0          1               1             1  37.0       2.0
#
#    Type_Occupation  Family_Members  label
# 0               12             2.0      1
# ...

# %%
df2.shape
# Out:
# (1541, 15)

# %% [markdown]
# # Feature scaling

# %%
from re import X

#feature scaling
from sklearn.model_selection import train_test_split
#split the data in to x and y
# 80% train and rest 20 % for testing
x=df2.drop(columns='label',axis=1)
y=df2['label']
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=0) # random state is for reprodcibility

# %%
x.head()
# Out:
#     Ind_ID  Gender  Car_Owner  Propert_Owner  Children  Annual_income  \
# 0  5008827       1          1              1         0   180000.00000
# 1  5009744       0          1              0         0   315000.00000
# 2  5009746       0          1              0         0   315000.00000
# 3  5009749       0          1              0         0   191399.32623
# 4  5009752       0          1              0         0   315000.00000
#
#    Type_Income  Education  Marital_status  Housing_type   Age  Work_exp  \
# 0            1          1               1             1  51.0       0.0
# 1            0          1               1             1  37.0       2.0
# 2            0          1               1             1  44.0       2.0
# 3            0          1               1             1  37.0       2.0
# 4            0          1               1             1  37.0       2.0
#
#    Type_Occupation  Family_Members
# 0               12             2.0
# 1               12             2.0
# ...

# %%
y
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 1543    0
# 1544    0
# 1545    0
# 1546    0
# 1547    0
# Name: label, Length: 1541, dtype: int64

# %%
x_train
# Out:
#        Ind_ID  Gender  Car_Owner  Propert_Owner  Children  Annual_income  \
# 204   5041273       1          0              1         0       380250.0
# 906   5067949       0          0              1         0       157500.0
# 1289  5023706       0          0              1         0       180000.0
# 702   5125585       0          0              1         0       121500.0
# 871   5044939       1          0              1         2       360000.0
# ...       ...     ...        ...            ...       ...            ...
# 770   5088101       0          1              1         0       270000.0
# 842   5033797       0          1              1         0       148500.0
# 1223  5125775       0          0              1         0       112500.0
# 566   5028684       1          0              1         0       157500.0
# 691   5029251       1          0              1         0       157500.0
#
#       Type_Income  Education  Marital_status  Housing_type   Age  Work_exp  \
# ...

# %%
x_test
# Out:
#        Ind_ID  Gender  Car_Owner  Propert_Owner  Children  Annual_income  \
# 900   5051008       0          0              0         1       225000.0
# 1000  5146114       0          0              1         0       157500.0
# 990   5045255       0          0              1         1       270000.0
# 1498  5011032       0          0              1         1       135000.0
# 1514  5051097       0          0              0         0        69750.0
# ...       ...     ...        ...            ...       ...            ...
# 1398  5068807       1          1              1         1       112500.0
# 1032  5028616       1          0              1         1       135000.0
# 1378  5010226       0          1              1         1        90000.0
# 616   5079035       0          0              1         0       135000.0
# 127   5117313       0          0              1         1       157500.0
#
#       Type_Income  Education  Marital_status  Housing_type   Age  Work_exp  \
# ...

# %%
y_train.shape
# Out:
# (1155,)

# %%
y_train
# Out:
# 204     0
# 906     0
# 1289    0
# 702     0
# 871     0
#        ..
# 770     0
# 842     0
# 1223    0
# 566     0
# 691     0
# Name: label, Length: 1155, dtype: int64

# %%
# performing transformation of data
#importing MinMaxScaler,
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0,1))
rescale_x_train=scaler.fit_transform(x_train)
rescale_x_test=scaler.fit_transform(x_test)

# %%
x.columns
# Out:
# Index(['Ind_ID', 'Gender', 'Car_Owner', 'Propert_Owner', 'Children',
#        'Annual_income', 'Type_Income', 'Education', 'Marital_status',
#        'Housing_type', 'Age', 'Work_exp', 'Type_Occupation', 'Family_Members'],
#       dtype='object')

# %%
rescale_x_train
# Out:
# array([[0.22916269, 1.        , 0.        , ..., 0.17073171, 0.66666667,
#         0.        ],
#        [0.41757248, 0.        , 0.        , ..., 0.24390244, 0.66666667,
#         0.        ],
#        [0.10508882, 0.        , 0.        , ..., 0.36585366, 0.44444444,
#         0.28571429],
#        ...,
#        [0.82599145, 0.        , 0.        , ..., 0.02439024, 0.66666667,
#         0.28571429],
#        [0.14024791, 1.        , 0.        , ..., 0.19512195, 0.44444444,
#         0.28571429],
#        [0.14425257, 1.        , 0.        , ..., 0.29268293, 0.44444444,
#         0.28571429]])

# %%
rescale_x_test
# Out:
# array([[0.29655143, 0.        , 0.        , ..., 0.25      , 0.82352941,
#         0.57142857],
#        [0.97126783, 0.        , 0.        , ..., 0.86111111, 0.70588235,
#         0.        ],
#        [0.25573757, 0.        , 0.        , ..., 0.27777778, 0.17647059,
#         0.57142857],
#        ...,
#        [0.00722915, 0.        , 1.        , ..., 0.61111111, 0.64705882,
#         0.57142857],
#        [0.49538512, 0.        , 0.        , ..., 0.        , 0.70588235,
#         0.28571429],
#        [0.76694311, 0.        , 0.        , ..., 0.30555556, 0.47058824,
#         0.57142857]])

# %%
df2["label"].value_counts()
# Out:
# 0    1371
# 1     170
# Name: label, dtype: int64

# %% [markdown]
# In the above the dataset shows imbalanced data values

# %% [markdown]
# # Model Training on different algorithms

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
log_r=LogisticRegression()
log_r.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
#Evaluate the model using y_test = original values based on x_test
y_pred=log_r.predict(x_test)

# %%
df2["label"].value_counts()
# Out:
# 0    1371
# 1     170
# Name: label, dtype: int64

# %%
#importing confusion metrics from sklearn library.
from sklearn.metrics import confusion_matrix,accuracy_score,precision_score,recall_score,f1_score
print("logistic regression training dataset:",log_r.score(x_train,y_train))
print("logistic regression testing dataset:",log_r.score(x_test,y_test))
print("Accuracy of logistic regreesion classifier:",accuracy_score(y_test,y_pred))
print(confusion_matrix(y_test,y_pred))
# Out:
# logistic regression training dataset: 0.8900432900432901
# logistic regression testing dataset: 0.8886010362694301
# Accuracy of logistic regreesion classifier: 0.8886010362694301
# [[343   0]
#  [ 43   0]]

# %% [markdown]
# # Cross validation

# %%
from sklearn.model_selection import StratifiedKFold,cross_val_score
model=LogisticRegression()
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=0)
result= cross_val_score(model, x, y, cv=skf, scoring='accuracy')
print(result)
print(np.mean(result))
# Out:
# [0.88996764 0.88961039 0.88961039 0.88961039 0.88961039]
# 0.8896818391964023

# %%
from sklearn.model_selection import ShuffleSplit,cross_val_score
model=LogisticRegression()
split = ShuffleSplit(n_splits=5, test_size=0.25, random_state=0)
result= cross_val_score(model, x, y, cv=split, scoring='accuracy')
print(result)
print(np.mean(result))
# Out:
# [0.88860104 0.90673575 0.85233161 0.9015544  0.89378238]
# 0.88860103626943

# %% [markdown]
# # DecisionTree

# %%
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier()
dt.fit(x_train,y_train)
y_pred=dt.predict(x_test)
print("Accuracy:",accuracy_score(y_test,y_pred))
print(confusion_matrix(y_test,y_pred))
# Out:
# Accuracy: 0.8704663212435233
# [[320  23]
#  [ 27  16]]

# %%
#cross validation
from sklearn.model_selection import ShuffleSplit
model= DecisionTreeClassifier()
ssplit=ShuffleSplit(n_splits=10,test_size=0.20)
from sklearn.model_selection import cross_val_score
results=cross_val_score(model,x,y,cv=ssplit)
print(results)
print(np.mean(results))
# Out:
# [0.86084142 0.87378641 0.85760518 0.85436893 0.82524272 0.85113269
#  0.86407767 0.85113269 0.87055016 0.87378641]
# 0.858252427184466

# %% [markdown]
# # RandomForestClassifier

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix
from sklearn import metrics
rf=RandomForestClassifier()
rf.fit(rescale_x_train,y_train)
y_pred=rf.predict(x_test)
print("Accuracy:",rf.score(x_test,y_test))
print(confusion_matrix(y_test,y_pred))
# Out:
# Accuracy: 0.772020725388601
# [[295  48]
#  [ 40   3]]

# %%
# cross validation
from sklearn.model_selection import ShuffleSplit
model= DecisionTreeClassifier()
ssplit=ShuffleSplit(n_splits=10,test_size=0.20)
from sklearn.model_selection import cross_val_score
results=cross_val_score(model,x,y,cv=ssplit)
print(results)
print(np.mean(results))
# Out:
# [0.86407767 0.84789644 0.87378641 0.85760518 0.84789644 0.8802589
#  0.86084142 0.85760518 0.86084142 0.82847896]
# 0.8579288025889967

# %% [markdown]
# # XGBoost

# %%
from xgboost import XGBClassifier
xgb=XGBClassifier()
xgb.fit(x_train,y_train)
y_pred=xgb.predict(x_test)
print(metrics.accuracy_score(y_test,y_pred))
print(confusion_matrix(y_test,y_pred))
# Out:
# 0.9119170984455959
# [[341   2]
#  [ 32  11]]

# %%
# cross validation
from sklearn.model_selection import ShuffleSplit
model=XGBClassifier()
ssplit=ShuffleSplit(n_splits=10,test_size=0.20)
from sklearn.model_selection import cross_val_score
results=cross_val_score(model,x,y,cv=ssplit)
print(results)
print(np.mean(results))
# Out:
# [0.91909385 0.91262136 0.92880259 0.91585761 0.90614887 0.91909385
#  0.91262136 0.90938511 0.94174757 0.90291262]
# 0.9168284789644012

# %% [markdown]
# # Imbalanced data checking on the Models

# %%
models={
    "Logisitic Regression" :LogisticRegression(max_iter=20000),
    "Decision Tree" :DecisionTreeClassifier(),
    "Random Forest":RandomForestClassifier(),
    #"K-Nearest Neighbors": KNeighborsClassifier(n_neighbors=3)
}

for i in range(len(list(models))):
    model = list(models.values())[i]
    model.fit(x_train,y_train.values.ravel()) # Train Model

    # Make predictions
    y_train_pred = model.predict(x_train)
    y_test_pred =  model.predict(x_test)

  # Performance of Test set
    model_test_accuracy = accuracy_score(y_test, y_test_pred)
    model_test_f1 = f1_score(y_test, y_test_pred, average='weighted')
    model_test_precision = precision_score(y_test, y_test_pred , average='weighted')
    model_test_recall  = recall_score(y_test, y_test_pred,average='weighted')

  # Performance of Training set
    model_train_accuracy = accuracy_score(y_train, y_train_pred)
    model_train_f1 = f1_score(y_train, y_train_pred, average= 'weighted')
    model_train_precision = precision_score(y_train, y_train_pred,average='weighted')
    model_train_recall = recall_score(y_train, y_train_pred,average='weighted')

    print(list(models.keys())[i])

    print('Model performance for Training set')
    print("- Accuracy: {:.2f}".format(model_train_accuracy))
    print('- F1 score: {:2f}'.format(model_train_f1))
    print('- Precision: {:2f}'.format(model_train_precision))
    print('- Recall: {:2f}'.format(model_train_recall))

    print('----------------------------------')

    print('Model performance for Test set')
    print('- Accuracy: {:.2f}'.format(model_test_accuracy) )
    print('- Fl score: {:.2f}'.format(model_test_f1))
    print('- Precision: {:.2f}'.format(model_test_precision))
    print('- Recall: {:.2f}'.format(model_test_recall))


    print('='*30)
    print('\n')
# Out:
# Logisitic Regression
# Model performance for Training set
# - Accuracy: 0.89
# - F1 score: 0.838263
# - Precision: 0.792177
# - Recall: 0.890043
# ----------------------------------
# Model performance for Test set
# - Accuracy: 0.89
# - Fl score: 0.84
# - Precision: 0.79
# - Recall: 0.89
# ...
#
#
# Decision Tree
# Model performance for Training set
# - Accuracy: 1.00
# - F1 score: 1.000000
# - Precision: 1.000000
# - Recall: 1.000000
# ----------------------------------
# Model performance for Test set
# - Accuracy: 0.87
# - Fl score: 0.86
# - Precision: 0.86
# - Recall: 0.87
# ...
#
#
# Random Forest
# Model performance for Training set
# - Accuracy: 1.00
# - F1 score: 1.000000
# - Precision: 1.000000
# - Recall: 1.000000
# ----------------------------------
# Model performance for Test set
# - Accuracy: 0.92
# - Fl score: 0.90
# - Precision: 0.92
# - Recall: 0.92
# ...

# %% [markdown]
# Assuptions:-

# %% [markdown]
# Initial Hypothesis(or hypotheses)
#
# Assuptions:-Logistic regression is going to work better than other algorithms for this dataset.
#
# 2. A person with low income is not getting his credit  card approval.
#
# To prove this assuptioms from this dataset i done some operations on the dataset as data analysis and ml track  data cleaning, EDA Visualzation of data,handling missing values,Rename column names,converting negative values to positive values, impuitation,feature Enginnering and scaling the data for train the model and the model data is test. after that model on different algorithms. I obsered the insights of this datasets between the categorial variable relationship and numerical variables.

# %% [markdown]
# 1.What approach are you going to take in order to prove or disprove your hypothesis?
#
# A:-In this credit card approval project the best approach that null hypothesis of my assumption logistic regression is going better than other algorithm is accept because there is no futher evidances to prove the aasuptions .
# 2.yes the lower annual income has less chance for credit card approval.
#
#
#
#
# 2.What feature engineering techniques will be relevant to your project?
# A:-The feature eningeering techniques for my project are feacture scaling,the mean value is 0 ans std= 1 for feature scaling mormalization,MinMaxscalar,rescaled the values and train and test the model .
#
#
#
#
#
# 3.Please justify your data analysis approach.
#
# A:- Data analysis for this project is that the relationship with the existing data with the target variable that the categorical variable relatuion with annual income,type_occupatuion and type _income is going to predict the target avriable of the label column.
#
#
#
#
# 4.Identify important patterns in your data using the EDA approach to justify your findings.
#
# A:- I apply different pattern for plotting visualization are barplot,boxplot, hisplot and more scatterplot for the multi variant analysis, pie_charts etc for the data visualis=zation mainly boxplot with handling outliers in some columns .Annual income and age with work_exp and credit card approval or not approval on label column.

# %% [markdown]
# Section 4: Machine learning approach
#
# What method will you use for machine learning based predictions for credit card approval?
#
# Please justify the most appropriate model.
#
# Please perform necessary steps required to improve the accuracy of your model.
#
# Please compare all models (at least 4  models).

# %% [markdown]
# The choice of a specific machine learning method for credit card approval prediction depends on various factors, and the balance between false positives and false negatives. Here are some common machine learning methods that are often used for binary classification tasks like credit card approval prediction i tried on four model alogrithms are are Logestic regession,DecisionTree,Xgboost and RandomForestClassifier to predict the better performace in accauracy.To impove the accuracy scaled the values and again apply train and test and model the data on alogrithm to get better accuracy , recall, precision and f1-score for the performance testing and the cross validation and hypertunning is better for  felxibity of best fit model.

# %% [markdown]
# # conclusion

# %% [markdown]
# # In this the best accuracy model for this credit card approval prediction is 'XGBoost' and logistic regression i got the best accuracy with both model algorithms XGBOOst with 91% accuracy and Logistic Regression is 88% accuracy.
